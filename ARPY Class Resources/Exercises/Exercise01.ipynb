# %% [markdown]
# ### Anonymous Access Properties

# %%
from arcgis.gis import GIS

# %%
gis = GIS()
gis

# %%
gis.properties.helperServices

# %% [markdown]
# ### Access the Training Services Organization

# %%
gis_EdOrg = GIS("https://www.arcgis.com","auto101_ts","12Arc.Union",profile="TrainingOrg")
gis_EdOrg

# %%
gis_EdOrg.users

# %%
gis_EdOrg.properties
