# %%
from arcgis.gis import GIS

# %%
gis = GIS('https://www.arcgis.com', 'viewer012', 'Training12345!')
gis.users.me
# Out:
# <User username:viewer012>

# %%
dir(gis.users.me)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_existence',
#  '_get_role',
#  '_gis',
#  '_group_dict',
#  '_hydrate',
#  '_hydrated',
#  '_invitemgr',
#  '_portal',
#  '_repr_html_',
#  '_resource_manager',
#  '_transfer_content_status',
#  '_user_id',
#  '_workdir',
#  'access',
#  'assignedCredits',
#  'availableCredits',
#  'bundles',
# ...

# %%
gis.users.search()
# Out:
# [<User username:JaneDoe0>,
#  <User username:JohnDoe748>,
#  <User username:mhnudi>,
#  <User username:Tester0>,
#  <User username:tkinlaw>,
#  <User username:viewer012>]

# %%
gis.content.search('')
# Out:
# [<Item title:"Training the model" type:StoryMap owner:tkinlaw>,
#  <Item title:"Testing profile variables" type:Web Map owner:tkinlaw>,
#  <Item title:"ArcGIS Knowledge Python Scripts - Backup and Create Knowledge Graph" type:Image Collection owner:tkinlaw>,
#  <Item title:"KNOW_1_0" type:Image Collection owner:tkinlaw>,
#  <Item title:"Exporting training samples" type:StoryMap owner:tkinlaw>,
#  <Item title:"Building detection exercise alternatives" type:StoryMap owner:tkinlaw>,
#  <Item title:"Slope" type:Tiled Imagery Layer owner:tkinlaw>,
#  <Item title:"Yosemite" type:Web Map owner:tkinlaw>,
#  <Item title:"Yosemite_WFL1" type:Feature Layer Collection owner:tkinlaw>,
#  <Item title:"DM4package" type:Map Image Layer owner:tkinlaw>]
