# %%
from arcgis.gis import GIS

# %%
url = r'https://ebase.ad.local/portal/home'

# %%
gis = GIS(url, 'tkinlaw_ent', 'Esri.4.GIS')
gis
# Out:
# GIS @ https://ebase.ad.local/portal version:2025.2

# %%
hostingServer = gis.servers['servers'][0]['id']

# %%
gis2 = GIS(url, client_id='YVMn3Qzj8xuKuXuV')
gis2
# Out:
# Please sign in to your GIS and paste the code that is obtained below.
# If a web browser does not automatically open, please navigate to the URL below yourself instead.
# Opening web browser to navigate to: https://ebase.ad.local/portal/sharing/rest/oauth2/authorize?response_type=code&client_id=YVMn3Qzj8xuKuXuV&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&state=q039nFjxBJQ4IxtCz7C3GqhupXwfVb&allow_verification=false
