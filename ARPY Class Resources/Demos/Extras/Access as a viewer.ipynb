# %%
from arcgis.gis import GIS

# %%
gis = GIS("https://www.arcgis.com", "Viewer012", 'Training12345!')
gis.users.me
# Out:
# <User username:viewer012>

# %%
item = gis.content.search('Feature Layer')[0]

# %%
item.delete()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 item.delete()
#
# File c:\Users\tim10393\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\gis\__init__.py:16764, in Item.delete(self, force, dry_run, permanent)
#   16760     else:
#   16761         _log.warning(
#   16762             "Recycle bin not enabled on this organization. Permanent delete parameter ignored."
#   16763         )
# > 16764 return self._portal.delete_item(self.itemid, self._user_id, folder, force)
#
# File c:\Users\tim10393\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgis\gis\_impl\_portalpy.py:778, in Portal.delete_item(self, item_id, owner, folder, force, permanent)
#     775 if permanent:
#     776     # applicable to online 2024.2 if recycle bin is enabled
# ...
