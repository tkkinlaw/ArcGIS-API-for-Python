# %%
from arcgis.gis import GIS
from getpass import getpass

# %%
url = r'https://www.arcgis.com/'
targetFolder = 'ARPY Exercises'

# %%
gisTarget = GIS(url, 'tkinlaw_EsriEdDelivery', getpass())
gisTarget
# Out:
# GIS @ https://EsriEdDelivery.maps.arcgis.com version:2025.3

# %%
gisSource = GIS(url, 'tkinlaw', '10June2019!')
gisSource
# Out:
# GIS @ https://kinlaw.maps.arcgis.com version:2025.3

# %%
contentList = [item for item in gisSource.content.folders.get('ARPY Exercises').list()]
print(len(contentList))
# Out:
# 45

# %%
gisTarget.content.clone_items(contentList, folder=targetFolder)
print('Items cloned')
# Out:
# C:\Users\tim10393\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'esrieddelivery.maps.arcgis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\tim10393\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'esrieddelivery.maps.arcgis.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
